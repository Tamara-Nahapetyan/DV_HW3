# %% [markdown]
# <a href="https://colab.research.google.com/github/Tamara-Nahapetyan/DV_HW3/blob/main/HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("2020.csv")
df
# Out:
#                  Country name  Happiness Rank  Happiness score  Upperwhisker  \
# 0                     Finland               1             7.81          7.87
# 1                     Denmark               2             7.65          7.71
# 2                 Switzerland               3             7.56          7.63
# 3                     Iceland               4             7.50          7.62
# 4                      Norway               5             7.49          7.56
# ..                        ...             ...              ...           ...
# 148  Central African Republic             149             3.48          3.70
# 149                    Rwanda             150             3.31          3.42
# 150                  Zimbabwe             151             3.30          3.41
# 151               South Sudan             152             2.82          3.03
# 152               Afghanistan             153             2.57          2.63
#
#      Lowerwhisker  Economy (GDP per Capita)\t  Social support  \
# 0            7.75                        1.29            1.50
# 1            7.58                        1.33            1.50
# 2            7.49                        1.39            1.47
# 3            7.39                        1.33            1.55
# 4            7.42                        1.42            1.50
# ..            ...                         ...             ...
# 148          3.25                        0.04            0.00
# 149          3.21                        0.34            0.52
# 150          3.18                        0.43            1.05
# 151          2.61                        0.29            0.55
# 152          2.51                        0.30            0.36
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                       0.96                          0.66        0.16
# 1                       0.98                          0.67        0.24
# 2                       1.04                          0.63        0.27
# 3                       1.00                          0.66        0.36
# 4                       1.01                          0.67        0.29
# ..                       ...                           ...         ...
# 148                     0.00                          0.29        0.25
# 149                     0.57                          0.60        0.24
# 150                     0.38                          0.38        0.15
# 151                     0.21                          0.07        0.21
# 152                     0.27                          0.00        0.14
#
#      Perceptions of corruption
# 0                         0.48
# 1                         0.50
# 2                         0.41
# 3                         0.14
# 4                         0.43
# ..                         ...
# 148                       0.03
# 149                       0.49
# 150                       0.08
# 151                       0.11
# 152                       0.00
#
# [153 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# Country name                    0
# Happiness Rank                  0
# Happiness score                 0
# Upperwhisker                    0
# Lowerwhisker                    0
# Economy (GDP per Capita)\t      0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
df.columns = df.columns.str.strip().str.replace(' ', '_').str.replace(r'[()]', '', regex=True)

df.rename(columns={'Economy_GDP_per_Capita': 'GDP_per_Capita'}, inplace=True)

df.columns
# Out:
# Index(['Country_name', 'Happiness_Rank', 'Happiness_score', 'Upperwhisker',
#        'Lowerwhisker', 'GDP_per_Capita', 'Social_support',
#        'Healthy_life_expectancy', 'Freedom_to_make_life_choices', 'Generosity',
#        'Perceptions_of_corruption'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Country_name                     object
# Happiness_Rank                    int64
# Happiness_score                 float64
# Upperwhisker                    float64
# Lowerwhisker                    float64
# GDP_per_Capita                  float64
# Social_support                  float64
# Healthy_life_expectancy         float64
# Freedom_to_make_life_choices    float64
# Generosity                      float64
# Perceptions_of_corruption       float64
# dtype: object

# %%
df
# Out:
#                  Country_name  Happiness_Rank  Happiness_score  Upperwhisker  \
# 0                     Finland               1             7.81          7.87
# 1                     Denmark               2             7.65          7.71
# 2                 Switzerland               3             7.56          7.63
# 3                     Iceland               4             7.50          7.62
# 4                      Norway               5             7.49          7.56
# ..                        ...             ...              ...           ...
# 148  Central African Republic             149             3.48          3.70
# 149                    Rwanda             150             3.31          3.42
# 150                  Zimbabwe             151             3.30          3.41
# 151               South Sudan             152             2.82          3.03
# 152               Afghanistan             153             2.57          2.63
#
#      Lowerwhisker  GDP_per_Capita  Social_support  Healthy_life_expectancy  \
# 0            7.75            1.29            1.50                     0.96
# 1            7.58            1.33            1.50                     0.98
# 2            7.49            1.39            1.47                     1.04
# 3            7.39            1.33            1.55                     1.00
# 4            7.42            1.42            1.50                     1.01
# ..            ...             ...             ...                      ...
# 148          3.25            0.04            0.00                     0.00
# 149          3.21            0.34            0.52                     0.57
# 150          3.18            0.43            1.05                     0.38
# 151          2.61            0.29            0.55                     0.21
# 152          2.51            0.30            0.36                     0.27
#
#      Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption
# 0                            0.66        0.16                       0.48
# 1                            0.67        0.24                       0.50
# 2                            0.63        0.27                       0.41
# 3                            0.66        0.36                       0.14
# 4                            0.67        0.29                       0.43
# ..                            ...         ...                        ...
# 148                          0.29        0.25                       0.03
# 149                          0.60        0.24                       0.49
# 150                          0.38        0.15                       0.08
# 151                          0.07        0.21                       0.11
# 152                          0.00        0.14                       0.00
#
# [153 rows x 11 columns]

# %%
df.describe()
# Out:
#        Happiness_Rank  Happiness_score  Upperwhisker  Lowerwhisker  \
# count      153.000000       153.000000    153.000000    153.000000
# mean        77.000000         5.473203      5.578431      5.368301
# std         44.311398         1.112110      1.096647      1.128770
# min          1.000000         2.570000      2.630000      2.510000
# 25%         39.000000         4.720000      4.830000      4.600000
# 50%         77.000000         5.510000      5.610000      5.430000
# 75%        115.000000         6.230000      6.360000      6.140000
# max        153.000000         7.810000      7.870000      7.750000
#
#        GDP_per_Capita  Social_support  Healthy_life_expectancy  \
# count      153.000000      153.000000               153.000000
# mean         0.868889        1.155294                 0.693072
# std          0.372560        0.287001                 0.254189
# min          0.000000        0.000000                 0.000000
# 25%          0.580000        0.990000                 0.500000
# 50%          0.920000        1.200000                 0.760000
# 75%          1.170000        1.390000                 0.870000
# max          1.540000        1.550000                 1.140000
#
#        Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption
# count                    153.000000  153.000000                 153.000000
# mean                       0.463529    0.189542                   0.130588
# std                        0.140981    0.100094                   0.113092
# min                        0.000000    0.000000                   0.000000
# 25%                        0.380000    0.120000                   0.060000
# 50%                        0.480000    0.180000                   0.100000
# 75%                        0.580000    0.260000                   0.160000
# max                        0.690000    0.570000                   0.530000

# %%
for country in df['Country_name']:
    print(country)
# Out:
# Finland
# Denmark
# Switzerland
# Iceland
# Norway
# Netherlands
# Sweden
# New Zealand
# Austria
# Luxembourg
# Canada
# Australia
# United Kingdom
# Israel
# Costa Rica
# Ireland
# Germany
# United States
# Czech Republic
# Belgium
# United Arab Emirates
# Malta
# France
# Mexico
# Taiwan Province of China
# Uruguay
# Saudi Arabia
# Spain
# Guatemala
# Italy
# Singapore
# Brazil
# Slovenia
# El Salvador
# Kosovo
# Panama
# Slovakia
# Uzbekistan
# Chile
# Bahrain
# Lithuania
# Trinidad and Tobago
# Poland
# Colombia
# Cyprus
# Nicaragua
# Romania
# Kuwait
# Mauritius
# Kazakhstan
# Estonia
# Philippines
# Hungary
# Thailand
# Argentina
# Honduras
# Latvia
# Ecuador
# Portugal
# Jamaica
# South Korea
# Japan
# Peru
# Serbia
# Bolivia
# Pakistan
# Paraguay
# Dominican Republic
# Bosnia and Herzegovina
# Moldova
# Tajikistan
# Montenegro
# Russia
# Kyrgyzstan
# Belarus
# North Cyprus
# Greece
# Hong Kong S.A.R. of China
# Croatia
# Libya
# Mongolia
# Malaysia
# Vietnam
# Indonesia
# Ivory Coast
# Benin
# Maldives
# Congo (Brazzaville)
# Azerbaijan
# Macedonia
# Ghana
# Nepal
# Turkey
# China
# Turkmenistan
# Bulgaria
# Morocco
# Cameroon
# Venezuela
# Algeria
# Senegal
# Guinea
# Niger
# Laos
# Albania
# Cambodia
# Bangladesh
# Gabon
# South Africa
# Iraq
# Lebanon
# Burkina Faso
# Gambia
# Mali
# Nigeria
# Armenia
# Georgia
# Iran
# Jordan
# Mozambique
# Kenya
# Namibia
# Ukraine
# Liberia
# Palestinian Territories
# Uganda
# Chad
# Tunisia
# Mauritania
# Sri Lanka
# Congo (Kinshasa)
# Swaziland
# Myanmar
# Comoros
# Togo
# Ethiopia
# Madagascar
# Egypt
# Sierra Leone
# Burundi
# Zambia
# Haiti
# Lesotho
# India
# Malawi
# Yemen
# Botswana
# Tanzania
# Central African Republic
# Rwanda
# Zimbabwe
# South Sudan
# Afghanistan

# %%
region_mapping = {
    'Finland': 'Western Europe',
    'Denmark': 'Western Europe',
    'Switzerland': 'Western Europe',
    'Iceland': 'Western Europe',
    'Norway': 'Western Europe',
    'Rwanda': 'Sub-Saharan Africa',
    'Zimbabwe': 'Sub-Saharan Africa',
    'South Sudan': 'Sub-Saharan Africa',
    'Afghanistan': 'South Asia',
    'India': 'South Asia',
    'Netherlands': 'Western Europe',
    'Sweden': 'Western Europe',
    'New Zealand': 'Australia and New Zealand',
    'Austria': 'Western Europe',
    'Luxembourg': 'Western Europe',
    'Canada': 'North America',
    'Australia': 'Australia and New Zealand',
    'United Kingdom': 'Western Europe',
    'Israel': 'Middle East and North Africa',
    'Costa Rica': 'Latin America and Caribbean',
    'Ireland': 'Western Europe',
    'Germany': 'Western Europe',
    'United States': 'North America',
    'Czech Republic': 'Central and Eastern Europe',
    'Belgium': 'Western Europe',
    'United Arab Emirates': 'Middle East and North Africa',
    'Malta': 'Western Europe',
    'France': 'Western Europe',
    'Mexico': 'Latin America and Caribbean',
    'Taiwan Province of China': 'East Asia',
    'Uruguay': 'Latin America and Caribbean',
    'Saudi Arabia': 'Middle East and North Africa',
    'Spain': 'Western Europe',
    'Guatemala': 'Latin America and Caribbean',
    'Italy': 'Western Europe',
    'Singapore': 'Southeast Asia',
    'Brazil': 'Latin America and Caribbean',
    'Slovenia': 'Central and Eastern Europe',
    'El Salvador': 'Latin America and Caribbean',
    'Kosovo': 'Central and Eastern Europe',
    'Panama': 'Latin America and Caribbean',
    'Slovakia': 'Central and Eastern Europe',
    'Uzbekistan': 'Central Asia',
    'Chile': 'Latin America and Caribbean',
    'Bahrain': 'Middle East and North Africa',
    'Lithuania': 'Central and Eastern Europe',
    'Trinidad and Tobago': 'Latin America and Caribbean',
    'Poland': 'Central and Eastern Europe',
    'Colombia': 'Latin America and Caribbean',
    'Cyprus': 'Middle East and North Africa',
    'Nicaragua': 'Latin America and Caribbean',
    'Romania': 'Central and Eastern Europe',
    'Kuwait': 'Middle East and North Africa',
    'Mauritius': 'Sub-Saharan Africa',
    'Kazakhstan': 'Central Asia',
    'Estonia': 'Central and Eastern Europe',
    'Philippines': 'Southeast Asia',
    'Hungary': 'Central and Eastern Europe',
    'Thailand': 'Southeast Asia',
    'Argentina': 'Latin America and Caribbean',
    'Honduras': 'Latin America and Caribbean',
    'Latvia': 'Central and Eastern Europe',
    'Ecuador': 'Latin America and Caribbean',
    'Portugal': 'Western Europe',
    'Jamaica': 'Latin America and Caribbean',
    'South Korea': 'East Asia',
    'Japan': 'East Asia',
    'Peru': 'Latin America and Caribbean',
    'Serbia': 'Central and Eastern Europe',
    'Bolivia': 'Latin America and Caribbean',
    'Pakistan': 'South Asia',
    'Paraguay': 'Latin America and Caribbean',
    'Dominican Republic': 'Latin America and Caribbean',
    'Bosnia and Herzegovina': 'Central and Eastern Europe',
    'Moldova': 'Central and Eastern Europe',
    'Tajikistan': 'Central Asia',
    'Montenegro': 'Central and Eastern Europe',
    'Russia': 'Central and Eastern Europe',
    'Kyrgyzstan': 'Central Asia',
    'Belarus': 'Central and Eastern Europe',
    'North Cyprus': 'Middle East and North Africa',
    'Greece': 'Western Europe',
    'Hong Kong S.A.R. of China': 'East Asia',
    'Croatia': 'Central and Eastern Europe',
    'Libya': 'Middle East and North Africa',
    'Mongolia': 'East Asia',
    'Malaysia': 'Southeast Asia',
    'Vietnam': 'Southeast Asia',
    'Indonesia': 'Southeast Asia',
    'Ivory Coast': 'Sub-Saharan Africa',
    'Benin': 'Sub-Saharan Africa',
    'Maldives': 'South Asia',
    'Congo (Brazzaville)': 'Sub-Saharan Africa',
    'Azerbaijan': 'Central Asia',
    'Macedonia': 'Central and Eastern Europe',
    'Ghana': 'Sub-Saharan Africa',
    'Nepal': 'South Asia',
    'Turkey': 'Middle East and North Africa',
    'China': 'East Asia',
    'Turkmenistan': 'Central Asia',
'Bulgaria': 'Central and Eastern Europe',
    'Morocco': 'Middle East and North Africa',
    'Cameroon': 'Sub-Saharan Africa',
    'Venezuela': 'Latin America and Caribbean',
    'Algeria': 'Middle East and North Africa',
    'Senegal': 'Sub-Saharan Africa',
    'Guinea': 'Sub-Saharan Africa',
    'Niger': 'Sub-Saharan Africa',
    'Laos': 'Southeast Asia',
    'Albania': 'Central and Eastern Europe',
    'Cambodia': 'Southeast Asia',
    'Bangladesh': 'South Asia',
    'Gabon': 'Sub-Saharan Africa',
    'South Africa': 'Sub-Saharan Africa',
    'Iraq': 'Middle East and North Africa',
    'Lebanon': 'Middle East and North Africa',
    'Burkina Faso': 'Sub-Saharan Africa',
    'Gambia': 'Sub-Saharan Africa',
    'Mali': 'Sub-Saharan Africa',
    'Nigeria': 'Sub-Saharan Africa',
    'Armenia': 'Central and Eastern Europe',
    'Georgia': 'Central and Eastern Europe',
    'Iran': 'Middle East and North Africa',
    'Jordan': 'Middle East and North Africa',
    'Mozambique': 'Sub-Saharan Africa',
    'Kenya': 'Sub-Saharan Africa',
    'Namibia': 'Sub-Saharan Africa',
    'Ukraine': 'Central and Eastern Europe',
    'Liberia': 'Sub-Saharan Africa',
    'Palestinian Territories': 'Middle East and North Africa',
    'Uganda': 'Sub-Saharan Africa',
    'Chad': 'Sub-Saharan Africa',
    'Tunisia': 'Middle East and North Africa',
    'Mauritania': 'Sub-Saharan Africa',
    'Sri Lanka': 'South Asia',
    'Congo (Kinshasa)': 'Sub-Saharan Africa',
    'Swaziland': 'Sub-Saharan Africa',
    'Myanmar': 'Southeast Asia',
    'Comoros': 'Sub-Saharan Africa',
    'Togo': 'Sub-Saharan Africa',
    'Ethiopia': 'Sub-Saharan Africa',
    'Madagascar': 'Sub-Saharan Africa',
    'Egypt': 'Middle East and North Africa',
    'Sierra Leone': 'Sub-Saharan Africa',
    'Burundi': 'Sub-Saharan Africa',
    'Zambia': 'Sub-Saharan Africa',
    'Haiti': 'Latin America and Caribbean',
    'Lesotho': 'Sub-Saharan Africa',
    'Malawi': 'Sub-Saharan Africa',
    'Yemen': 'Middle East and North Africa',
    'Botswana': 'Sub-Saharan Africa',
    'Tanzania': 'Sub-Saharan Africa',
    'Central African Republic': 'Sub-Saharan Africa'
}

df['Region'] = df['Country_name'].map(region_mapping)
df = df.dropna(subset=['Region'])
region_avg = df.groupby('Region')['Happiness_score'].mean().sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x=region_avg.values, y=region_avg.index, palette="viridis")
plt.title('Average Happiness Score by Region')
plt.xlabel('Average Happiness Score')
plt.ylabel('Region')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-125-4e79303bc1ef>:162: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=region_avg.values, y=region_avg.index, palette="viridis")

# %%
from scipy.stats import pearsonr
corr, p_value = pearsonr(df['GDP_per_Capita'], df['Happiness_score'])

print(f"Hypothesis 1 - GDP vs Happiness")
print(f"Pearson correlation: {corr:.3f}")
print(f"P-value: {p_value:.4f}")

if p_value < 0.05:
    print("Reject the null hypothesis. Significant positive correlation.")
else:
    print("Fail to reject the null hypothesis. No significant correlation.")
# Out:
# Hypothesis 1 - GDP vs Happiness
# Pearson correlation: 0.775
# P-value: 0.0000
# Reject the null hypothesis. Significant positive correlation.

# %%
corr, p_value = pearsonr(df['Freedom_to_make_life_choices'], df['Happiness_score'])

print(f"\nHypothesis 3 - Freedom vs Happiness")
print(f"Pearson correlation: {corr:.3f}")
print(f"P-value: {p_value:.4f}")

if p_value < 0.05:
    print("Reject the null hypothesis. Significant positive correlation.")
else:
    print("Fail to reject the null hypothesis. No significant correlation.")
# Out:
# Hypothesis 3 - Freedom vs Happiness
# Pearson correlation: 0.591
# P-value: 0.0000
# Reject the null hypothesis. Significant positive correlation.

# %%
corr, p_value = pearsonr(df['Perceptions_of_corruption'], df['Happiness_score'])

print(f"\nHypothesis 4 - Corruption vs Happiness")
print(f"Pearson correlation: {corr:.3f}")
print(f"P-value: {p_value:.4f}")

if p_value < 0.05:
    print("Reject the null hypothesis. Significant negative correlation.")
else:
    print("Fail to reject the null hypothesis. No significant correlation.")
# Out:
# Hypothesis 4 - Corruption vs Happiness
# Pearson correlation: 0.418
# P-value: 0.0000
# Reject the null hypothesis. Significant negative correlation.

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlation Between Happiness Score and Other Factors')
plt.show()

# %%
features = [
    'GDP_per_Capita',
    'Social_support',
    'Healthy_life_expectancy',
    'Freedom_to_make_life_choices',
    'Generosity',
    'Perceptions_of_corruption'
]

plt.figure(figsize=(18, 12))
for i, feature in enumerate(features):
    plt.subplot(2, 3, i + 1)
    sns.scatterplot(data=df, x=feature, y='Happiness_score')
    plt.title(f'{feature.replace("_", " ")} vs Happiness Score')
    plt.xlabel(feature.replace("_", " "))
    plt.ylabel('Happiness Score')

plt.tight_layout()
plt.show()

# %%
top10 = df.sort_values(by='Happiness_score', ascending=False).head(10)
sns.barplot(data=top10, x='Happiness_score', y='Country_name')
plt.title('Top 10 Happiest Countries')
plt.xlabel('Happiness Score')
plt.ylabel('Country')
plt.show()

# %%
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

# %%
color = 'purple'
plt.figure(figsize=(15, 10))
selected_cols = numeric_cols[:6]
for i, col in enumerate(selected_cols):
    plt.subplot(2, 3, i+1)
    sns.boxplot(x=df[col], color=color)
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
f, ax = plt.subplots(figsize=(15, 5))

sns.set(color_codes=True)
sns.kdeplot(df['Happiness_score'], fill=True, color="green")

plt.title("Happiness Score Distribution", fontsize=16)
plt.xlabel("Happiness Score")
plt.ylabel("Density")
plt.show()

# %%
f, ax = plt.subplots(figsize=(15,5))

sns.histplot(data = df, x = 'Happiness_score', kde=True);
